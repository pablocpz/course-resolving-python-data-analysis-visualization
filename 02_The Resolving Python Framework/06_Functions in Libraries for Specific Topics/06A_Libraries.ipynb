# %% [markdown]
# # Functions in Libraries for Specific Topics

# %% [markdown]
# Most problems, at the beginning, require you tu use **functions from a library**.
#
# 1. Libraries contain functions for specific topics.
# 2. Therefore, if you know the topic of your problem.
# 3. You'll know in which library you could discover the function you need.

# %% [markdown]
# Let me show you examples from two libraries to understand why they contain functions for specific topics.

# %% [markdown]
# ## Libraries' Examples
#
# ❌ Don't pay attention to the full code.
#
# ✅ Just pay attention to the library and the resulting object.

# %% [markdown]
# ### Seaborn (Graphs & Plots)
#
# Seaborn is a python library for data visualization that contains functions to plot figures. Therefore, you can see how we get different figures as we execute different functions from the `seaborn` library:
#
# > You identify the `functions()` everytime you see the parenthesis and the characters in lower case. For example, `scatterplot()`.

# %%
import seaborn as sns #!

# %% [markdown]
# #### Scatter plot

# %%
sns.scatterplot(x=[1,3,5,7,9], y=[2,-2,2,-2,2]); #!

# %% [markdown]
# #### Line plot

# %%
sns.lineplot(x=[1,3,5,7,9], y=[2,-2,2,-2,2]); #!

# %% [markdown]
# #### Bar plot

# %%
sns.barplot(x=[1,3,5,7,9], y=[2,-2,2,-2,2]); #!

# %% [markdown]
# ### Pandas (Data Tables)

# %% [markdown]
# Pandas is a python library for data tables containing functions to load and analyze. In the following examples, you can see how pandas loads different types of file:

# %%
import pandas as pd#!

# %% [markdown]
# #### Excel

# %%
pd.read_excel('russia-world-cup.xlsx', index_col='Team') #!
# Out:
#               Games Played  Wins  Draws  Losses  Points Accumulated  \
# Team
# Argentina                4     1      1       2                   4
# Australia                3     0      1       2                   1
# Belgium                  7     6      0       1                  18
# Brazil                   5     3      1       1                  10
# Colombia                 4     2      1       1                   7
# Costa Rica               3     0      1       2                   1
# Croatia                  7     4      2       1                  14
# Denmark                  4     1      3       0                   6
# Egypt                    3     0      0       3                   0
# England                  7     3      1       3                  10
# France                   7     6      1       0                  19
# Germany                  3     1      0       2                   3
# Iceland                  3     0      1       2                   1
# Iran                     3     1      1       1                   4
# Japan                    4     1      1       2                   4
# Mexico                   4     2      0       2                   6
# Morocco                  3     0      1       2                   1
# Nigeria                  3     1      0       2                   3
# Panama                   3     0      0       3                   0
# Peru                     3     1      0       2                   3
# Poland                   3     1      0       2                   3
# Portugal                 4     1      2       1                   5
# Russia                   5     2      2       1                   8
# Saudi Arabia             3     1      0       2                   3
# Senegal                  3     1      1       1                   4
# Serbia                   3     1      0       2                   3
# South Korea              3     1      0       2                   3
# Spain                    4     1      3       0                   6
# Sweden                   5     3      0       2                   9
# Switzerland              4     1      2       1                   5
# Tunisia                  3     1      0       2                   3
# Uruguay                  5     4      0       1                  12
#
#               Average Points per Game  Goals Scored  Average Goals per Game  \
# Team
# Argentina                        1.00             6                    1.50
# Australia                        0.33             2                    0.67
# Belgium                          2.57            16                    2.29
# Brazil                           2.00             8                    1.60
# Colombia                         1.75             6                    1.50
# Costa Rica                       0.33             2                    0.67
# Croatia                          2.00            14                    2.00
# Denmark                          1.50             3                    0.75
# Egypt                            0.00             2                    0.67
# England                          1.43            12                    1.71
# France                           2.71            14                    2.00
# Germany                          1.00             2                    0.67
# Iceland                          0.33             2                    0.67
# Iran                             1.33             2                    0.67
# Japan                            1.00             6                    1.50
# Mexico                           1.50             3                    0.75
# Morocco                          0.33             2                    0.67
# Nigeria                          1.00             3                    1.00
# Panama                           0.00             2                    0.67
# Peru                             1.00             2                    0.67
# Poland                           1.00             2                    0.67
# Portugal                         1.25             6                    1.50
# Russia                           1.60            11                    2.20
# Saudi Arabia                     1.00             2                    0.67
# Senegal                          1.33             4                    1.33
# Serbia                           1.00             2                    0.67
# South Korea                      1.00             3                    1.00
# Spain                            1.50             7                    1.75
# Sweden                           1.80             6                    1.20
# Switzerland                      1.25             5                    1.25
# Tunisia                          1.00             5                    1.67
# Uruguay                          2.40             7                    1.40
#
#               Goals Conceded  Average Goals Conceded per Game Goal Difference  \
# Team
# Argentina                  9                             2.25              −3
# Australia                  5                             1.67              −3
# Belgium                    6                             0.86             +10
# Brazil                     3                             0.60              +5
# Colombia                   3                             0.75              +3
# Costa Rica                 5                             1.67              −3
# Croatia                    9                             1.29              +5
# Denmark                    2                             0.50              +1
# Egypt                      6                             2.00              −4
# England                    8                             1.14              +4
# France                     6                             0.86              +8
# Germany                    4                             1.33              −2
# Iceland                    5                             1.67              −3
# Iran                       2                             0.67               0
# Japan                      7                             1.75              −1
# Mexico                     6                             1.50              −3
# Morocco                    4                             1.33              −2
# Nigeria                    4                             1.33              −1
# Panama                    11                             3.67              −9
# Peru                       2                             0.67               0
# Poland                     5                             1.67              −3
# Portugal                   6                             1.50               0
# Russia                     7                             1.40              +4
# Saudi Arabia               7                             2.33              −5
# Senegal                    4                             1.33               0
# Serbia                     4                             1.33              −2
# South Korea                3                             1.00               0
# Spain                      6                             1.50              +1
# Sweden                     4                             0.80              +2
# Switzerland                5                             1.25               0
# Tunisia                    8                             2.67              −3
# Uruguay                    3                             0.60              +4
#
#              Average Goal Difference  Clean Sheets  Average Clean Sheets  \
# Team
# Argentina                      −0.75             0                  0.00
# Australia                      −1.00             0                  0.00
# Belgium                         1.43             3                  0.43
# Brazil                          1.00             3                  0.60
# Colombia                        0.75             2                  0.50
# Costa Rica                     −1.00             0                  0.00
# Croatia                         0.71             2                  0.29
# Denmark                         0.25             2                  0.50
# Egypt                          −1.33             0                  0.00
# England                         0.57             1                  0.14
# France                          1.14             4                  0.57
# Germany                        −0.67             0                  0.00
# Iceland                        −1.00             0                  0.00
# Iran                            0.00             1                  0.33
# Japan                          −0.25             0                  0.00
# Mexico                         −0.75             1                  0.25
# Morocco                        −0.67             0                  0.00
# Nigeria                        −0.33             1                  0.33
# Panama                         −3.00             0                  0.00
# Peru                            0.00             1                  0.33
# Poland                         −1.00             1                  0.33
# Portugal                        0.00             1                  0.25
# Russia                          0.80             1                  0.20
# Saudi Arabia                   −1.67             0                  0.00
# Senegal                         0.00             0                  0.00
# Serbia                         −0.67             1                  0.33
# South Korea                     0.00             1                  0.33
# Spain                           0.25             1                  0.25
# Sweden                          0.40             3                  0.60
# Switzerland                     0.00             0                  0.00
# Tunisia                        −1.00             0                  0.00
# Uruguay                         0.80             3                  0.60
#
#               Yellow Cards  Average Yellow Cards  Red Cards  Average Red Cards
# Team
# Argentina               11                  2.75          0               0.00
# Australia                7                  2.33          0               0.00
# Belgium                 11                  1.57          0               0.00
# Brazil                   7                  1.40          0               0.00
# Colombia                 9                  2.25          1               0.25
# Costa Rica               6                  2.00          0               0.00
# Croatia                 15                  2.14          0               0.00
# Denmark                  6                  1.50          0               0.00
# Egypt                    5                  1.67          0               0.00
# England                  8                  1.14          0               0.00
# France                  12                  1.71          0               0.00
# Germany                  2                  0.67          1               0.33
# Iceland                  3                  1.00          0               0.00
# Iran                     7                  2.33          0               0.00
# Japan                    5                  1.25          0               0.00
# Mexico                   9                  2.25          0               0.00
# Morocco                  8                  2.67          0               0.00
# Nigeria                  4                  1.33          0               0.00
# Panama                  11                  3.67          0               0.00
# Peru                     5                  1.67          0               0.00
# Poland                   3                  1.00          0               0.00
# Portugal                 7                  1.75          0               0.00
# Russia                   6                  1.20          1               0.20
# Saudi Arabia             1                  0.33          0               0.00
# Senegal                  6                  2.00          0               0.00
# Serbia                   9                  3.00          0               0.00
# South Korea             10                  3.33          0               0.00
# Spain                    2                  0.50          0               0.00
# Sweden                   8                  1.60          0               0.00
# Switzerland              9                  2.25          1               0.25
# Tunisia                  4                  1.33          0               0.00
# Uruguay                  3                  0.60          0               0.00

# %% [markdown]
# #### CSV

# %%
pd.read_csv('best_tennis_players_stats.csv', index_col=0) #!
# Out:
#        income  titles  grand slams  turned professional  wins  losses
# roger     130     103           20                 1998  1251     275
# rafa      127      90           21                 2001  1038     209
# nole      154      86           20                 2003   989     199

# %% [markdown]
# #### HTML

# %% [markdown]
# The following case it's pretty cool because we get the data tables from websites, such as [the world population](https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population), directly with the function `read_html()`:

# %%
pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')[1] #!
# Out:
#     Rank                 Country / Dependency  Population                 \
#     Rank                 Country / Dependency     Numbers % of the world
# 0      –                                World  8029257000           100%
# 1      1                                China  1411750000            NaN
# 2      2                                India  1392329000            NaN
# 3      3                        United States   334726000            NaN
# 4      4                            Indonesia   277749853            NaN
# ..   ...                                  ...         ...            ...
# 237    –                Tokelau (New Zealand)        1647            NaN
# 238    –                                 Niue        1549            NaN
# 239  195                         Vatican City         825            NaN
# 240    –  Cocos (Keeling) Islands (Australia)         593            NaN
# 241    –    Pitcairn Islands (United Kingdom)          47            NaN
#
#             Date Source (official or from the United Nations) Notes
#             Date Source (official or from the United Nations) Notes
# 0     8 May 2023                             UN projection[3]   NaN
# 1    31 Dec 2022                         Official estimate[4]   [b]
# 2     1 Mar 2023                       Official projection[5]   [c]
# 3     8 May 2023                 National population clock[7]   [d]
# 4    31 Dec 2022                         Official estimate[8]   NaN
# ..           ...                                          ...   ...
# 237   1 Jan 2019                            2019 Census [208]   NaN
# 238   1 Jul 2021               National annual projection[95]   NaN
# 239   1 Feb 2019               Monthly national estimate[209]  [ag]
# 240  30 Jun 2020                             2021 Census[210]   NaN
# 241   1 Jul 2021                       Official estimate[211]   NaN
#
# [242 rows x 7 columns]

# %% [markdown]
# ## Restaurants Analogy (🇯🇵 🇮🇹 🇪🇸)
#
# Let's make the idea simpler, imagine:
#
# 1. Shopping mall (Computer)
# 2. Restaurant section (Python)
# 3. Restaurants: japanese, italian, spanish,... (Python Libraries)
# 4. Chefs (Functions) will cook the meal (the output)
# 5. Ingredients (Parameters) the chef needs to cook your meal

# %% [markdown]
# ## Conclusion
#
# So, we can deduce that:
#
# 1. If your topic is related to **chart & plots**, you'll try to find the function in `seaborn`.
# 2. If your topic is related to **data tables**, you'll try to find the function in `pandas` library.
# 3. And many [other topics and libraries](https://www.craft.do/s/G80r1dqrQKrjTb/b/E566C8E4-176F-4160-B530-AEF34FBAFFC4/Library).
#
# Now it's time to apply these ideas to practical exercises!

# %% [markdown]
# # What's Next?
#
# - Practice with exercises on the next section.
